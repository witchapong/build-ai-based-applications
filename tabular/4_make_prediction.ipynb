# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/witchapong/build-ai-based-applications/blob/main/tabular/4_make_prediction.ipynb)

# %% [markdown]
# # Stock Price Prediction using ML model
# In this session, we'll learn how to build a ML model for predicting **%change of stock prices of the next day** of stocks in SET index (Stock Exchange of Thailand). Thus, we should be able to use the prediction to buy stocks that are going up the next day, make profits, and hopefully get rich!
#
# This session is divided into the following 5 notebooks.
# 1. `1_collect_data.ipynb`
# 2. `2_eda.ipynb`
# 3. `3_features_prep.ipynb`
# 4. `4_make_prediction.ipynb` (current notebook)
# 5. `5_evaluation.ipynb`

# %%
# # mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
from pathlib import Path

# running on Colab
DATA_DIR = Path("/content/drive/MyDrive/build-ai-based-applications/")

# # running on local
# DATA_DIR = Path(".")

# %% [markdown]
# # Make Prediction
# So far, we've already prepared the features from the previous step. In this notebook, we'll finally train a ML model and use it to make prediction of return on the next day. However, before we can feed the features to a model, we need to do some more data processing step for converting any non-numerical feature column into number as a ML model only accept numerical representation of data i.e. String needs to be encoded as Interger.

# %%
from tqdm.notebook import tqdm

import numpy as np
import pandas as pd
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

idx = pd.IndexSlice

import lightgbm as lgb

import math
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Load and Process Features

# %%
data_df = pd.read_csv(DATA_DIR / "data/model_data.csv")

# %%
data_df = data_df.set_index(["symbol", "date"])

# %%
# encode categorical variables
categoricals = ["year", "month", "weekday", "industry", "sector"]

for feat in categoricals:
    data_df[feat] = pd.factorize(data_df[feat], sort=True)[0]

# %%
labels = sorted(data_df.filter(like="_fwd").columns)
features = data_df.columns.difference(labels).tolist()

# %%
data_df.head()
# Out:
#                     open   high   low  close     volume  dividends  \
# symbol date
# 24CS   2022-10-03   7.10  10.20  7.10  10.20  559465900        0.0
#        2022-10-04  10.70  11.10  7.15   7.15  330707400        0.0
#        2022-10-05   5.85   6.45  5.05   5.15  361028900        0.0
#        2022-10-06   5.40   5.45  4.70   5.20  232679200        0.0
#        2022-10-07   5.10   5.15  4.76   5.00  131778400        0.0
#
#                    stock splits        value  val_rank  rsi  bb_high  bb_low  \
# symbol date
# 24CS   2022-10-03           0.0  5706.552073       1.0  NaN      NaN     NaN
#        2022-10-04           0.0  2364.557942       1.0  NaN      NaN     NaN
#        2022-10-05           0.0  1859.298869       1.0  NaN      NaN     NaN
#        2022-10-06           0.0  1209.931796       2.0  NaN      NaN     NaN
#        2022-10-07           0.0   658.892000       2.0  NaN      NaN     NaN
#
#                    NATR  ATR  MACD  industry  sector       r01  r05  r10  r21  \
# symbol date
# 24CS   2022-10-03   NaN  NaN   NaN        17       7       NaN  NaN  NaN  NaN
#        2022-10-04   NaN  NaN   NaN        17       7 -0.299020  NaN  NaN  NaN
#        2022-10-05   NaN  NaN   NaN        17       7 -0.279720  NaN  NaN  NaN
#        2022-10-06   NaN  NaN   NaN        17       7  0.009709  NaN  NaN  NaN
#        2022-10-07   NaN  NaN   NaN        17       7 -0.038462  NaN  NaN  NaN
#
#                    r42  r63  r01dec  r05dec  r10dec  r21dec  r42dec  r63dec  \
# symbol date
# 24CS   2022-10-03  NaN  NaN     NaN     NaN     NaN     NaN     NaN     NaN
#        2022-10-04  NaN  NaN     0.0     NaN     NaN     NaN     NaN     NaN
#        2022-10-05  NaN  NaN     0.0     NaN     NaN     NaN     NaN     NaN
#        2022-10-06  NaN  NaN     4.0     NaN     NaN     NaN     NaN     NaN
#        2022-10-07  NaN  NaN     0.0     NaN     NaN     NaN     NaN     NaN
#
#                    r01q_sector  r05q_sector  r10q_sector  r21q_sector  \
# symbol date
# 24CS   2022-10-03          NaN          NaN          NaN          NaN
#        2022-10-04          0.0          NaN          NaN          NaN
#        2022-10-05          0.0          NaN          NaN          NaN
#        2022-10-06          3.0          NaN          NaN          NaN
#        2022-10-07          0.0          NaN          NaN          NaN
#
#                    r42q_sector  r63q_sector   r01_fwd   r05_fwd   r21_fwd  \
# symbol date
# 24CS   2022-10-03          NaN          NaN -0.299020 -0.509804 -0.592157
#        2022-10-04          NaN          NaN -0.279720 -0.373427 -0.454545
#        2022-10-05          NaN          NaN  0.009709 -0.246602 -0.254369
#        2022-10-06          NaN          NaN -0.038462 -0.292308 -0.276923
#        2022-10-07          NaN          NaN  0.000000 -0.224000 -0.268000
#
#                    income_stmt_taxEffectOfUnusualItems_p1y  \
# symbol date
# 24CS   2022-10-03                                      0.0
#        2022-10-04                                      0.0
#        2022-10-05                                      0.0
#        2022-10-06                                      0.0
#        2022-10-07                                      0.0
#
#                    income_stmt_taxRateForCalcs_p1y  \
# symbol date
# 24CS   2022-10-03                         0.241495
#        2022-10-04                         0.241495
#        2022-10-05                         0.241495
#        2022-10-06                         0.241495
#        2022-10-07                         0.241495
#
#                    income_stmt_normalizedEBITDA_p1y  \
# symbol date
# 24CS   2022-10-03                        35101165.0
#        2022-10-04                        35101165.0
#        2022-10-05                        35101165.0
#        2022-10-06                        35101165.0
#        2022-10-07                        35101165.0
#
#                    income_stmt_totalUnusualItems_p1y  \
# symbol date
# 24CS   2022-10-03                                0.0
#        2022-10-04                                0.0
#        2022-10-05                                0.0
#        2022-10-06                                0.0
#        2022-10-07                                0.0
#
#                    income_stmt_totalUnusualItemsExcludingGoodwill_p1y  \
# symbol date
# 24CS   2022-10-03                                                0.0
#        2022-10-04                                                0.0
#        2022-10-05                                                0.0
#        2022-10-06                                                0.0
#        2022-10-07                                                0.0
#
#                    income_stmt_netIncomeFromContinuingOperationNetMinorityInterest_p1y  \
# symbol date
# 24CS   2022-10-03                                         19455578.0
#        2022-10-04                                         19455578.0
#        2022-10-05                                         19455578.0
#        2022-10-06                                         19455578.0
#        2022-10-07                                         19455578.0
#
#                    income_stmt_reconciledDepreciation_p1y  \
# symbol date
# 24CS   2022-10-03                               6959244.0
#        2022-10-04                               6959244.0
#        2022-10-05                               6959244.0
#        2022-10-06                               6959244.0
#        2022-10-07                               6959244.0
#
#                    income_stmt_reconciledCostOfRevenue_p1y  \
# symbol date
# 24CS   2022-10-03                              563704474.0
#        2022-10-04                              563704474.0
#        2022-10-05                              563704474.0
#        2022-10-06                              563704474.0
#        2022-10-07                              563704474.0
#
#                    income_stmt_eBITDA_p1y  income_stmt_eBIT_p1y  \
# symbol date
# 24CS   2022-10-03              35101165.0            28141921.0
#        2022-10-04              35101165.0            28141921.0
#        2022-10-05              35101165.0            28141921.0
#        2022-10-06              35101165.0            28141921.0
#        2022-10-07              35101165.0            28141921.0
#
#                    income_stmt_netInterestIncome_p1y  \
# symbol date
# 24CS   2022-10-03                         -2013217.0
#        2022-10-04                         -2013217.0
#        2022-10-05                         -2013217.0
#        2022-10-06                         -2013217.0
#        2022-10-07                         -2013217.0
#
#                    income_stmt_interestExpense_p1y  ...  \
# symbol date                                         ...
# 24CS   2022-10-03                        2492033.0  ...
#        2022-10-04                        2492033.0  ...
#        2022-10-05                        2492033.0  ...
#        2022-10-06                        2492033.0  ...
#        2022-10-07                        2492033.0  ...
#
#                    income_stmt_normalizedIncome_p3y  \
# symbol date
# 24CS   2022-10-03                               NaN
#        2022-10-04                               NaN
#        2022-10-05                               NaN
#        2022-10-06                               NaN
#        2022-10-07                               NaN
#
#                    income_stmt_netIncomeFromContinuingAndDiscontinuedOperation_p3y  \
# symbol date
# 24CS   2022-10-03                                                NaN
#        2022-10-04                                                NaN
#        2022-10-05                                                NaN
#        2022-10-06                                                NaN
#        2022-10-07                                                NaN
#
#                    income_stmt_totalExpenses_p3y  \
# symbol date
# 24CS   2022-10-03                            NaN
#        2022-10-04                            NaN
#        2022-10-05                            NaN
#        2022-10-06                            NaN
#        2022-10-07                            NaN
#
#                    income_stmt_dilutedAverageShares_p3y  \
# symbol date
# 24CS   2022-10-03                                   NaN
#        2022-10-04                                   NaN
#        2022-10-05                                   NaN
#        2022-10-06                                   NaN
#        2022-10-07                                   NaN
#
#                    income_stmt_basicAverageShares_p3y  \
# symbol date
# 24CS   2022-10-03                                 NaN
#        2022-10-04                                 NaN
#        2022-10-05                                 NaN
#        2022-10-06                                 NaN
#        2022-10-07                                 NaN
#
#                    income_stmt_dilutedEPS_p3y  income_stmt_basicEPS_p3y  \
# symbol date
# 24CS   2022-10-03                         NaN                       NaN
#        2022-10-04                         NaN                       NaN
#        2022-10-05                         NaN                       NaN
#        2022-10-06                         NaN                       NaN
#        2022-10-07                         NaN                       NaN
#
#                    income_stmt_dilutedNIAvailtoComStockholders_p3y  \
# symbol date
# 24CS   2022-10-03                                              NaN
#        2022-10-04                                              NaN
#        2022-10-05                                              NaN
#        2022-10-06                                              NaN
#        2022-10-07                                              NaN
#
#                    income_stmt_netIncomeCommonStockholders_p3y  \
# symbol date
# 24CS   2022-10-03                                          NaN
#        2022-10-04                                          NaN
#        2022-10-05                                          NaN
#        2022-10-06                                          NaN
#        2022-10-07                                          NaN
#
#                    income_stmt_netIncome_p3y  \
# symbol date
# 24CS   2022-10-03                        NaN
#        2022-10-04                        NaN
#        2022-10-05                        NaN
#        2022-10-06                        NaN
#        2022-10-07                        NaN
#
#                    income_stmt_netIncomeIncludingNoncontrollingInterests_p3y  \
# symbol date
# 24CS   2022-10-03                                                NaN
#        2022-10-04                                                NaN
#        2022-10-05                                                NaN
#        2022-10-06                                                NaN
#        2022-10-07                                                NaN
#
#                    income_stmt_netIncomeContinuousOperations_p3y  \
# symbol date
# 24CS   2022-10-03                                            NaN
#        2022-10-04                                            NaN
#        2022-10-05                                            NaN
#        2022-10-06                                            NaN
#        2022-10-07                                            NaN
#
#                    income_stmt_taxProvision_p3y  income_stmt_pretaxIncome_p3y  \
# symbol date
# 24CS   2022-10-03                           NaN                           NaN
#        2022-10-04                           NaN                           NaN
#        2022-10-05                           NaN                           NaN
#        2022-10-06                           NaN                           NaN
#        2022-10-07                           NaN                           NaN
#
#                    income_stmt_otherIncomeExpense_p3y  \
# symbol date
# 24CS   2022-10-03                                 NaN
#        2022-10-04                                 NaN
#        2022-10-05                                 NaN
#        2022-10-06                                 NaN
#        2022-10-07                                 NaN
#
#                    income_stmt_otherNonOperatingIncomeExpenses_p3y  \
# symbol date
# 24CS   2022-10-03                                              NaN
#        2022-10-04                                              NaN
#        2022-10-05                                              NaN
#        2022-10-06                                              NaN
#        2022-10-07                                              NaN
#
#                    income_stmt_specialIncomeCharges_p3y  \
# symbol date
# 24CS   2022-10-03                                   NaN
#        2022-10-04                                   NaN
#        2022-10-05                                   NaN
#        2022-10-06                                   NaN
#        2022-10-07                                   NaN
#
#                    income_stmt_gainOnSaleOfPpe_p3y  \
# symbol date
# 24CS   2022-10-03                              NaN
#        2022-10-04                              NaN
#        2022-10-05                              NaN
#        2022-10-06                              NaN
#        2022-10-07                              NaN
#
#                    income_stmt_otherSpecialCharges_p3y  \
# symbol date
# 24CS   2022-10-03                                  NaN
#        2022-10-04                                  NaN
#        2022-10-05                                  NaN
#        2022-10-06                                  NaN
#        2022-10-07                                  NaN
#
#                    income_stmt_gainOnSaleOfSecurity_p3y  \
# symbol date
# 24CS   2022-10-03                                   NaN
#        2022-10-04                                   NaN
#        2022-10-05                                   NaN
#        2022-10-06                                   NaN
#        2022-10-07                                   NaN
#
#                    income_stmt_netNonOperatingInterestIncomeExpense_p3y  \
# symbol date
# 24CS   2022-10-03                                                NaN
#        2022-10-04                                                NaN
#        2022-10-05                                                NaN
#        2022-10-06                                                NaN
#        2022-10-07                                                NaN
#
#                    income_stmt_interestExpenseNonOperating_p3y  \
# symbol date
# 24CS   2022-10-03                                          NaN
#        2022-10-04                                          NaN
#        2022-10-05                                          NaN
#        2022-10-06                                          NaN
#        2022-10-07                                          NaN
#
#                    income_stmt_interestIncomeNonOperating_p3y  \
# symbol date
# 24CS   2022-10-03                                         NaN
#        2022-10-04                                         NaN
#        2022-10-05                                         NaN
#        2022-10-06                                         NaN
#        2022-10-07                                         NaN
#
#                    income_stmt_operatingIncome_p3y  \
# symbol date
# 24CS   2022-10-03                              NaN
#        2022-10-04                              NaN
#        2022-10-05                              NaN
#        2022-10-06                              NaN
#        2022-10-07                              NaN
#
#                    income_stmt_operatingExpense_p3y  \
# symbol date
# 24CS   2022-10-03                               NaN
#        2022-10-04                               NaN
#        2022-10-05                               NaN
#        2022-10-06                               NaN
#        2022-10-07                               NaN
#
#                    income_stmt_sellingGeneralAndAdministration_p3y  \
# symbol date
# 24CS   2022-10-03                                              NaN
#        2022-10-04                                              NaN
#        2022-10-05                                              NaN
#        2022-10-06                                              NaN
#        2022-10-07                                              NaN
#
#                    income_stmt_sellingAndMarketingExpense_p3y  \
# symbol date
# 24CS   2022-10-03                                         NaN
#        2022-10-04                                         NaN
#        2022-10-05                                         NaN
#        2022-10-06                                         NaN
#        2022-10-07                                         NaN
#
#                    income_stmt_generalAndAdministrativeExpense_p3y  \
# symbol date
# 24CS   2022-10-03                                              NaN
#        2022-10-04                                              NaN
#        2022-10-05                                              NaN
#        2022-10-06                                              NaN
#        2022-10-07                                              NaN
#
#                    income_stmt_otherGandA_p3y  \
# symbol date
# 24CS   2022-10-03                         NaN
#        2022-10-04                         NaN
#        2022-10-05                         NaN
#        2022-10-06                         NaN
#        2022-10-07                         NaN
#
#                    income_stmt_salariesAndWages_p3y  \
# symbol date
# 24CS   2022-10-03                               NaN
#        2022-10-04                               NaN
#        2022-10-05                               NaN
#        2022-10-06                               NaN
#        2022-10-07                               NaN
#
#                    income_stmt_grossProfit_p3y  income_stmt_costOfRevenue_p3y  \
# symbol date
# 24CS   2022-10-03                          NaN                            NaN
#        2022-10-04                          NaN                            NaN
#        2022-10-05                          NaN                            NaN
#        2022-10-06                          NaN                            NaN
#        2022-10-07                          NaN                            NaN
#
#                    income_stmt_totalRevenue_p3y  \
# symbol date
# 24CS   2022-10-03                           NaN
#        2022-10-04                           NaN
#        2022-10-05                           NaN
#        2022-10-06                           NaN
#        2022-10-07                           NaN
#
#                    income_stmt_operatingRevenue_p3y  \
# symbol date
# 24CS   2022-10-03                               NaN
#        2022-10-04                               NaN
#        2022-10-05                               NaN
#        2022-10-06                               NaN
#        2022-10-07                               NaN
#
#                    income_stmt_minorityInterests_p3y  \
# symbol date
# 24CS   2022-10-03                                NaN
#        2022-10-04                                NaN
#        2022-10-05                                NaN
#        2022-10-06                                NaN
#        2022-10-07                                NaN
#
#                    income_stmt_impairmentOfCapitalAssets_p3y  \
# symbol date
# 24CS   2022-10-03                                        NaN
#        2022-10-04                                        NaN
#        2022-10-05                                        NaN
#        2022-10-06                                        NaN
#        2022-10-07                                        NaN
#
#                    income_stmt_totalOperatingIncomeAsReported_p3y  \
# symbol date
# 24CS   2022-10-03                                             NaN
#        2022-10-04                                             NaN
#        2022-10-05                                             NaN
#        2022-10-06                                             NaN
#        2022-10-07                                             NaN
#
#                    income_stmt_totalOtherFinanceCost_p3y  \
# symbol date
# 24CS   2022-10-03                                    NaN
#        2022-10-04                                    NaN
#        2022-10-05                                    NaN
#        2022-10-06                                    NaN
#        2022-10-07                                    NaN
#
#                    income_stmt_otherOperatingExpenses_p3y  \
# symbol date
# 24CS   2022-10-03                                     NaN
#        2022-10-04                                     NaN
#        2022-10-05                                     NaN
#        2022-10-06                                     NaN
#        2022-10-07                                     NaN
#
#                    income_stmt_depreciationAmortizationDepletionIncomeStatement_p3y  \
# symbol date
# 24CS   2022-10-03                                                NaN
#        2022-10-04                                                NaN
#        2022-10-05                                                NaN
#        2022-10-06                                                NaN
#        2022-10-07                                                NaN
#
#                    income_stmt_depreciationAndAmortizationInIncomeStatement_p3y  \
# symbol date
# 24CS   2022-10-03                                                NaN
#        2022-10-04                                                NaN
#        2022-10-05                                                NaN
#        2022-10-06                                                NaN
#        2022-10-07                                                NaN
#
#                    income_stmt_earningsFromEquityInterest_p3y  \
# symbol date
# 24CS   2022-10-03                                         NaN
#        2022-10-04                                         NaN
#        2022-10-05                                         NaN
#        2022-10-06                                         NaN
#        2022-10-07                                         NaN
#
#                    income_stmt_provisionForDoubtfulAccounts_p3y  \
# symbol date
# 24CS   2022-10-03                                           NaN
#        2022-10-04                                           NaN
#        2022-10-05                                           NaN
#        2022-10-06                                           NaN
#        2022-10-07                                           NaN
#
#                    income_stmt_rentExpenseSupplemental_p3y  \
# symbol date
# 24CS   2022-10-03                                      NaN
#        2022-10-04                                      NaN
#        2022-10-05                                      NaN
#        2022-10-06                                      NaN
#        2022-10-07                                      NaN
#
#                    income_stmt_writeOff_p3y  \
# symbol date
# 24CS   2022-10-03                       NaN
#        2022-10-04                       NaN
#        2022-10-05                       NaN
#        2022-10-06                       NaN
#        2022-10-07                       NaN
#
#                    income_stmt_netIncomeDiscontinuousOperations_p3y  \
# symbol date
# 24CS   2022-10-03                                               NaN
#        2022-10-04                                               NaN
#        2022-10-05                                               NaN
#        2022-10-06                                               NaN
#        2022-10-07                                               NaN
#
#                    income_stmt_gainOnSaleOfBusiness_p3y  year  month  weekday
# symbol date
# 24CS   2022-10-03                                   NaN     2      9        0
#        2022-10-04                                   NaN     2      9        1
#        2022-10-05                                   NaN     2      9        2
#        2022-10-06                                   NaN     2      9        3
#        2022-10-07                                   NaN     2      9        4
#
# [5 rows x 221 columns]

# %% [markdown]
# # Define Train and Test Periods
# We'll use 240 days of data to train a model and use the model for predicting the next 60 days of data. Then, we progressively roll our training data window by 60 days and again use the updated 240 days of data to train a model and make prediction of the next 60 days and so on.

# %%
TRAIN_LENGTH = 240
TEST_LENGTH = 60

trading_dates = np.sort(data_df.index.get_level_values("date").unique())
trading_dates[0], trading_dates[-1]
# Out:
# ('2020-01-02', '2024-12-30')

# %%
# calculate number of periods we need to train & predict based on our TRAIN_LENGTH and TEST_LENGTH
n_periods = math.ceil((len(data_df.index.get_level_values("date").unique()) - TRAIN_LENGTH) / TEST_LENGTH)
n_periods
# Out:
# 17

# %%
train_test_dates = []

for i in range(n_periods):
    train_start = i * TEST_LENGTH
    train_dates = trading_dates[train_start: train_start + TRAIN_LENGTH]
    test_dates  = trading_dates[train_start + TRAIN_LENGTH: min(train_start + TRAIN_LENGTH + TEST_LENGTH, len(trading_dates))]
    train_test_dates.append((train_dates, test_dates))

# %%
for i, (train_dates, test_dates) in enumerate(train_test_dates):
    print(f"Period {i+1}: Train dates from {train_dates[0]} to {train_dates[-1]}, Test dates from {test_dates[0]} to {test_dates[-1]}")
# Out:
# Period 1: Train dates from 2020-01-02 to 2020-12-25, Test dates from 2020-12-28 to 2021-03-25
# Period 2: Train dates from 2020-03-27 to 2021-03-25, Test dates from 2021-03-26 to 2021-06-29
# Period 3: Train dates from 2020-06-26 to 2021-06-29, Test dates from 2021-06-30 to 2021-09-27
# Period 4: Train dates from 2020-09-28 to 2021-09-27, Test dates from 2021-09-28 to 2021-12-24
# Period 5: Train dates from 2020-12-28 to 2021-12-24, Test dates from 2021-12-27 to 2022-03-23
# Period 6: Train dates from 2021-03-26 to 2022-03-23, Test dates from 2022-03-24 to 2022-06-27
# Period 7: Train dates from 2021-06-30 to 2022-06-27, Test dates from 2022-06-28 to 2022-09-23
# Period 8: Train dates from 2021-09-28 to 2022-09-23, Test dates from 2022-09-26 to 2022-12-23
# Period 9: Train dates from 2021-12-27 to 2022-12-23, Test dates from 2022-12-26 to 2023-03-21
# Period 10: Train dates from 2022-03-24 to 2023-03-21, Test dates from 2023-03-22 to 2023-06-22
# Period 11: Train dates from 2022-06-28 to 2023-06-22, Test dates from 2023-06-23 to 2023-09-19
# Period 12: Train dates from 2022-09-26 to 2023-09-19, Test dates from 2023-09-20 to 2023-12-18
# Period 13: Train dates from 2022-12-26 to 2023-12-18, Test dates from 2023-12-19 to 2024-03-15
# Period 14: Train dates from 2023-03-22 to 2024-03-15, Test dates from 2024-03-18 to 2024-06-19
# Period 15: Train dates from 2023-06-23 to 2024-06-19, Test dates from 2024-06-20 to 2024-09-16
# Period 16: Train dates from 2023-09-20 to 2024-09-16, Test dates from 2024-09-17 to 2024-12-13
# Period 17: Train dates from 2023-12-19 to 2024-12-13, Test dates from 2024-12-16 to 2024-12-30

# %% [markdown]
# # Train Model and Make Predictions
# Based on the defined train and test periods, we'll train a ML model on the train period and make prediction on the test period. We'll use [LightGBM](https://lightgbm.readthedocs.io/en/stable/Python-API.html#scikit-learn-api) model which is one of the most popular model among ML usecases for tabular data due to its performance and speed.

# %%
lgb_params = {
 'learning_rate': 0.01,
 'num_leaves': 4,
 'feature_fraction': 0.95,
 'min_data_in_leaf': 250,
 'boost_rounds': 200}

# %%
# for each period, train, make predictions, store predictions for evaluation
prediction_df = pd.DataFrame()
for train_dates, test_dates in tqdm(train_test_dates):

    train_df = data_df.loc[idx[:, train_dates], :]
    X_train, Y_train = train_df[features], train_df["r01_fwd"]

    model = lgb.LGBMRegressor(**lgb_params)
    model.fit(X_train, Y_train)

    test_df = data_df.loc[idx[:, test_dates], :]
    X_test = test_df[features]
    prediction = model.predict(X_test)

    prediction_df = pd.concat([prediction_df, pd.DataFrame(prediction, index=test_df.index, columns=["prediction"])], axis=0)
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027258 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5357
# [LightGBM] [Info] Number of data points in the train set: 168156, number of used features: 41
# [LightGBM] [Info] Start training from score 0.000822
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.849948 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5458
# [LightGBM] [Info] Number of data points in the train set: 169866, number of used features: 58
# [LightGBM] [Info] Start training from score 0.003224
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.104089 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18781
# [LightGBM] [Info] Number of data points in the train set: 172061, number of used features: 97
# [LightGBM] [Info] Start training from score 0.002404
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.148349 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18791
# [LightGBM] [Info] Number of data points in the train set: 174636, number of used features: 97
# [LightGBM] [Info] Start training from score 0.002407
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.088415 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18830
# [LightGBM] [Info] Number of data points in the train set: 177227, number of used features: 102
# [LightGBM] [Info] Start training from score 0.002073
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.097757 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18902
# [LightGBM] [Info] Number of data points in the train set: 179767, number of used features: 110
# [LightGBM] [Info] Start training from score 0.001153
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.258927 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 33198
# [LightGBM] [Info] Number of data points in the train set: 182212, number of used features: 157
# [LightGBM] [Info] Start training from score 0.000490
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.163994 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 33225
# [LightGBM] [Info] Number of data points in the train set: 184551, number of used features: 157
# [LightGBM] [Info] Start training from score 0.000311
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.159914 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 33277
# [LightGBM] [Info] Number of data points in the train set: 187167, number of used features: 162
# [LightGBM] [Info] Start training from score -0.000111
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.778320 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 33315
# [LightGBM] [Info] Number of data points in the train set: 190379, number of used features: 170
# [LightGBM] [Info] Start training from score -0.000233
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.240009 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 47651
# [LightGBM] [Info] Number of data points in the train set: 193106, number of used features: 217
# [LightGBM] [Info] Start training from score -0.000511
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.235342 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 47660
# [LightGBM] [Info] Number of data points in the train set: 195225, number of used features: 217
# [LightGBM] [Info] Start training from score -0.000511
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.246716 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 47683
# [LightGBM] [Info] Number of data points in the train set: 196448, number of used features: 217
# [LightGBM] [Info] Start training from score -0.000688
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 1.187316 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 47621
# [LightGBM] [Info] Number of data points in the train set: 196440, number of used features: 217
# [LightGBM] [Info] Start training from score -0.000489
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.391362 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48455
# [LightGBM] [Info] Number of data points in the train set: 196498, number of used features: 217
# [LightGBM] [Info] Start training from score -0.000620
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.284546 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48453
# [LightGBM] [Info] Number of data points in the train set: 196667, number of used features: 217
# [LightGBM] [Info] Start training from score -0.000303
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 1.284916 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48514
# [LightGBM] [Info] Number of data points in the train set: 196573, number of used features: 217
# [LightGBM] [Info] Start training from score -0.000193
# [LightGBM] [Warning] Unknown parameter: boost_rounds
# [LightGBM] [Warning] feature_fraction is set=0.95, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.95
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250

# %% [markdown]
# # Save Predictions

# %%
# save predictions
prediction_df = prediction_df.sort_index().reset_index()

# %%
prediction_df.head()
# Out:
#   symbol        date  prediction
# 0   24CS  2022-10-03   -0.000994
# 1   24CS  2022-10-04    0.003970
# 2   24CS  2022-10-05    0.003970
# 3   24CS  2022-10-06    0.001731
# 4   24CS  2022-10-07    0.002824

# %%
prediction_df.to_csv(DATA_DIR / "data/prediction.csv", index=False)
